# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from src.etl.loader import load_all_datasets

# %%
from pathlib import Path

BASE_DIR = Path.cwd().parent
RAW = BASE_DIR / "data" / "raw"

print(RAW)
# Out:
# c:\Users\panka\OneDrive\Desktop\Nifty100_Project\data\raw

# %%
for f in RAW.iterdir():
    print(f.name)
# Out:
# analysis.xlsx
# balancesheet.xlsx
# cashflow.xlsx
# companies.xlsx
# documents.xlsx
# Nifty100_Project_Document_FINAL.pdf
# profitandloss.xlsx
# prosandcons.xlsx
# supporting

# %%
support = RAW / "supporting datasets"

print(support.exists())

for f in support.iterdir():
    print(f.name)
# Out:
# True
# financial_ratios.xlsx
# market_cap.xlsx
# peer_groups.xlsx
# sectors.xlsx
# stock_prices.xlsx

# %%
datasets = load_all_datasets()

# %%
print(f"Total datasets: {len(datasets)}")

for name, df in datasets.items():
    print(f"{name:<20} {df.shape}")
# Out:
# Total datasets: 12
# companies            (93, 12)
# profitandloss        (1277, 15)
# balancesheet         (1313, 13)
# cashflow             (1188, 7)
# analysis             (21, 6)
# documents            (1586, 4)
# prosandcons          (17, 4)
# financial_ratios     (1184, 16)
# market_cap           (552, 9)
# peer_groups          (56, 4)
# sectors              (92, 6)
# stock_prices         (5520, 9)
